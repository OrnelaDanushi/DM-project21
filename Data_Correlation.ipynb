# %% [markdown]
# Caricamento file, da eliminare quando si mette insieme agli altri subtask

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
df = df = pd.read_csv('matches_with_gender.csv', index_col = 0)

# %% [markdown]
# ## Data Correlation
# We compute the correlation matrix related to the numerical attributes of the dataset.

# %%
matrix = df.corr() #use pearson
matrix
# Out:
#                     draw_size  tourney_date  match_num  winner_id  winner_ht  \
# draw_size            1.000000      0.051022   0.270213  -0.211249   0.018759
# tourney_date         0.051022      1.000000   0.085142   0.160846  -0.013548
# match_num            0.270213      0.085142   1.000000  -0.285763   0.069320
# winner_id           -0.211249      0.160846  -0.285763   1.000000  -0.503485
# winner_ht            0.018759     -0.013548   0.069320  -0.503485   1.000000
# winner_age           0.199777      0.004799   0.162903  -0.495656   0.118012
# loser_id            -0.218734      0.149017  -0.289177   0.896243  -0.510127
# loser_ht            -0.007200     -0.005079   0.049183  -0.541209   0.412717
# loser_age            0.206213      0.062022   0.177079  -0.347701   0.131299
# best_of              0.378014     -0.006724   0.032165  -0.195736   0.133758
# minutes              0.124134      0.064791   0.002851  -0.026169   0.038335
# ...

# %% [markdown]
# To visualize in a better way the correlation between numerical attributes we use heatmap. Cell's colors represent intensity of correlection between two attributes.

# %%
fig, ax = plt.subplots(figsize=(30, 30))         # Sample figsize in inches
sn.heatmap(matrix, annot=True)
plt.show()

# %%
#operazione troppo onerosa e poco chiara, meglio farla solo su attributi fortemente correlati(?)
#pd.plotting.scatter_matrix(df, figsize = (20,20))
#plt.show()

# %% [markdown]
# We visualize in scatter plot or scatter matrix the attributes that are very strong correleted (with a parameter >= 0.9)

# %%
#df.plot.scatter(x = 'draw_size', y = 'tourney_revenue')
pd.plotting.scatter_matrix(df[['draw_size', 'tourney_revenue', 'tourney_spectators']], figsize = (15, 10))
plt.show()

# %% [markdown]
# We visualize in a scatter plot the pair of attributes more similar:
# (posso estrarre le coppie di indici più correlate e poi andare a rappresentare gli scatter plot
#
# w_SvGms, l_SvGms
# draw_size, tourney_spectator
# draw_size, tourney_revenue
# l_bpSaved, l_bpFaced
# w_bpSaved, w_bpFaced
# l_1stWon, l_1stIn, l_svpt
# w_1stWon, w_1stIn, w_svpt

# %%
df.plot.scatter(x = 'w_SvGms', y = 'l_SvGms')

# %%
df.plot.scatter(x = 'l_bpSaved', y = 'l_bpFaced')
df.plot.scatter(x = 'w_bpSaved', y = 'w_bpFaced')

# %%
pd.plotting.scatter_matrix(df[['l_svpt', 'l_1stIn', 'l_1stWon']], figsize = (15, 10))
plt.show()

# %%
pd.plotting.scatter_matrix(df[['w_svpt', 'w_1stIn', 'w_1stWon']], figsize = (15, 10))
plt.show()

# %%
#df.plot.scatter(x = 'l_1stWon', y = 'l_1stIn')
#df.plot.scatter(x = 'l_1stIn', y = 'l_svpt')
#df.plot.scatter(x = 'l_svpt', y = 'l_1stWon')
#pd.plotting.scatter_matrix(df[['l_1stWon', 'l_1stIn', 'l_svpt']], figsize = (10, 10))
#plt.show()

# %%
df.plot.scatter(x = 'winner_id', y = 'loser_id')
